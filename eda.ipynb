# %% [markdown]
# ## Exploratory Data Analysis for Midway Checkpoint

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
cities_df = pd.read_csv("data/filtered_cities500_wide.csv")
ribcot_df = pd.read_csv("data/filtered_ribcot_2014.csv")
df = pd.merge(cities_df, ribcot_df, on=["State", "CityName"], how="inner")

# %%
# Select relevant columns
correlation_columns = ["bingedrinking", "smokingrate", "nophysicalactivity", "obesityrate", "sleepdeprivation", "cardiovascular"]
correlation_df = df[correlation_columns]

# Compute correlation matrix
correlation_matrix = correlation_df.corr()

# Plot the heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5)
plt.title("Correlation Between Cardiovascular Search Interest and Health Behaviors")
plt.show()

# %% [markdown]
# ## Visualization
#
# - Looking at the cardiovascular row, we can see that binge drinking actually has a negative correlation to cardiovascular related google search trends. On the ther hand, non physical activity and obesity rate seems to have a positive correlation to cardio vascular related search trends
# - We need to further check what health habits really affect our machine learning models by doing a SHAP analysis.
