# %% [markdown]
# ## Exploratory Data Analysis for Midway Checkpoint

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
cities_df = pd.read_csv("data/filtered_cities500_wide.csv")
ribcot_df = pd.read_csv("data/filtered_ribcot_2014.csv")
df = pd.merge(cities_df, ribcot_df, on=["State", "CityName"], how="inner")

# %%
df = df.select_dtypes(include = "number")
correlation = df.corr()["cardiovascular"].drop("cardiovascular").sort_values(ascending=False)

# plot the correlation as a boxplot
plt.figure(figsize=(10, 6))
correlation.plot(kind="bar", color="skyblue", edgecolor="black")

# plot the visual
plt.xlabel("Features")
plt.ylabel("Correlation with Cardiovascular Disease")
plt.title("Feature Correlation with Cardiovascular Disease")
plt.xticks(rotation=45, ha="right")

plt.show()

# %% [markdown]
# ## Visualization
#
# - We can take away from this visualization that obesity and diabetes is one of the biggest indicators of cardiovascular disease.
# - To further understand how our machine learning algorithms may behave, we need to conduct ML algorithms and conduct SHAP analyses to see which features really affect our different ML models.
